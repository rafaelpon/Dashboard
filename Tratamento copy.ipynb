# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

# %%
df.shape #Dimenções
# Out:
# (607, 12)

# %%
df.head(23)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# 5            5       2020               EN              FT
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
# 11          11       2020               MI              FT
# 12          12       2020               EN              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
# ...

# %%
df.isnull().sum() #valores nulos

# %%
df.duplicated().sum() #valores duplicados

# %%
df=df.drop(["salary","salary_currency"],axis=1)

# %%
df = df.drop(63)

# %%
# Salvando os dados tratados em um novo arquivo CSV
df.to_csv('dados_tratados.csv', index=False)

# %%
dfe = pd.read_csv(r'D:\Biblioteca\Nova pasta - Copia\Projeto PA\dados_tratados.csv')

# %%
df.head(64)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# ..         ...        ...              ...             ...
# 59          59       2020               MI              FT
# 60          60       2020               MI              FT
# 61          61       2020               MI              FT
# 62          62       2020               EN              PT
# 64          64       2020               SE              FT
#
#                      job_title  salary_in_usd employee_residence  \
# 0               Data Scientist          79833                 DE
# 1   Machine Learning Scientist         260000                 JP
# ...

# %%
idade_procurada = 412000
linha_procurada = df[df['salary_in_usd'] == idade_procurada]

# Exibir a linha encontrada
print(linha_procurada)
# Out:
#     Unnamed: 0  work_year experience_level employment_type       job_title  \
# 63          63       2020               SE              FT  Data Scientist
#
#     salary_in_usd employee_residence  remote_ratio company_location  \
# 63         412000                 US           100               US
#
#    company_size
# 63            L
